# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhilth123/Learning-basics-of-llms/blob/main/pandas_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
country=['india','nepal','japan','pakistan','bhutan']
pd.Series(country)
# Out:
# 0       india
# 1       nepal
# 2       japan
# 3    pakistan
# 4      bhutan
# dtype: object

# %%
runs=[5,6,78,99,100,120];
run_ser=pd.Series(runs)

# %%
marks=[67,99,98,97,96,100]
subjects=['hindi','maths','english','geo','polity','history']
pd.Series(marks,index=subjects)
# Out:
# hindi       67
# maths       99
# english     98
# geo         97
# polity      96
# history    100
# dtype: int64

# %%
pd.Series(marks,index=subjects,name='Nikhil ')
# Out:
# hindi       67
# maths       99
# english     98
# geo         97
# polity      96
# history    100
# Name: Nikhil , dtype: int64

# %%
marks={
    'hindi':90,
    'english':88,
    'maths':98,
    'geo':97,
    'polity':96,
    'history':100
}
pd.Series(marks,name='nikhil')
# Out:
# hindi       90
# english     88
# maths       98
# geo         97
# polity      96
# history    100
# Name: nikhil, dtype: int64

# %%
marks=pd.Series(marks,index=subjects,name='Nikhil')
marks
# Out:
# hindi       90
# maths       98
# english     88
# geo         97
# polity      96
# history    100
# Name: Nikhil, dtype: int64

# %%
#size
marks.size
# Out:
# 6

# %%
#name
marks.name
# Out:
# 'Nikhil'

# %%
#dtype
marks.dtype
# Out:
# dtype('int64')

# %%
#unique
marks.is_unique
# Out:
# True

# %%
pd.Series([1,2,2,4,5,9,9]).is_unique
# Out:
# False

# %%
#index
marks.index
# Out:
# Index(['hindi', 'maths', 'english', 'geo', 'polity', 'history'], dtype='object')

# %%
run_ser.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
#values
run_ser.values
# Out:
# array([  5,   6,  78,  99, 100, 120])

# %%
type(marks.values)
# Out:
# numpy.ndarray

# %%
bolly=pd.read_csv('/content/BollywoodMovieDetail.csv')
bolly
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# ...

# %%
print(bolly.columns)
# Out:
# Index(['imdbId', 'title', 'releaseYear', 'releaseDate', 'genre', 'writers',
#        'actors', 'directors', 'sequel', 'hitFlop'],
#       dtype='object')

# %% [markdown]
# Now, let's select the 'MovieName' column to see that it is a Series:

# %%
movie_names_series = bolly['title']
display(movie_names_series.head())
print(type(movie_names_series))
# Out:
# 0                               Albela
# 1    Lagaan: Once Upon a Time in India
# 2             Meri Biwi Ka Jawab Nahin
# 3               Hum Tumhare Hain Sanam
# 4                           One 2 Ka 4
# Name: title, dtype: object
# <class 'pandas.core.series.Series'>

# %%
movie_names_series.mode()
# Out:
# 0                         ...Yahaan
# 1       13B: Fear Has a New Address
# 2                       16 December
# 3                              1920
# 4                1920: Evil Returns
#                    ...
# 1279       Zindagi Na Milegi Dobara
# 1280              Zindagi Tere Naam
# 1281                       Zokkomon
# 1282         Zor Lagaa Ke... Haiya!
# 1283                       Zubeidaa
# Name: title, Length: 1284, dtype: object

# %%
movie_names_series.describe()
# Out:
# count     1284
# unique    1284
# top        Zid
# freq         1
# Name: title, dtype: object
