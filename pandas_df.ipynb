# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhilth123/Learning-basics-of-llms/blob/main/pandas_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#creating dataframe
student_data=[
    [130,45,15],
    [34,12,12],
    [23,23,45],
    [56,67,89]
]
pd.DataFrame(student_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  130     45       15
# 1   34     12       12
# 2   23     23       45
# 3   56     67       89

# %%
students_dict={
    'iq':[130,34,23,56],
    'marks':[45,12,23,67],
    'package':[15,12,45,89]

};
students=pd.DataFrame(students_dict)
students
# Out:
#     iq  marks  package
# 0  130     45       15
# 1   34     12       12
# 2   23     23       45
# 3   56     67       89

# %%
movies=pd.read_csv('/content/BollywoodMovieDetail.csv')
movies
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 0     tt0118578                             Albela         2001  20 Apr 2001
# 1     tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2     tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3     tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4     tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# ...         ...                                ...          ...          ...
# 1279  tt4121522               Shuruaat Ka Interval         2014  15 Aug 2014
# 1280  tt4187650                   Trip to Bhangarh         2014  28 Aug 2014
# 1281  tt4190220                           Zed Plus         2014  28 Nov 2014
# 1282  tt4219300                    Gollu aur Pappu         2014  21 Nov 2014
# 1283  tt4228746                                Zid         2014  28 Nov 2014
#
#                             genre  \
# ...

# %%
player=pd.read_csv('/content/2024_players_details.csv')
player
# Out:
#          ID               Name                longName        battingName  \
# 0     95094         RD Gaikwad         Ruturaj Gaikwad         RD Gaikwad
# 1     46597             MM Ali               Moeen Ali             MM Ali
# 2    116328   Aravelly Avanish        Aravelly Avanish   Aravelly Avanish
# 3     62022          DL Chahar           Deepak Chahar          DL Chahar
# 4     80607       TU Deshpande        Tushar Deshpande       TU Deshpande
# ..      ...                ...                     ...                ...
# 256   59261         JD Unadkat          Jaydev Unadkat         JD Unadkat
# 257  102870       V Viyaskanth  Vijayakanth Viyaskanth       V Viyaskanth
# 258   75311  Washington Sundar       Washington Sundar  Washington Sundar
# 259   75985           UD Yadav           Upendra Yadav           UD Yadav
# 260   78239       PW Hasaranga       Wanindu Hasaranga       PW Hasaranga
#
#           fieldingName                                             imgUrl  \
# ...

# %%
movies.shape
# Out:
# (1284, 10)

# %%
player.shape
# Out:
# (261, 13)

# %%
movies.dtypes
# Out:
# imdbId          object
# title           object
# releaseYear      int64
# releaseDate     object
# genre           object
# writers         object
# actors          object
# directors       object
# sequel         float64
# hitFlop          int64
# dtype: object

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=1284, step=1)

# %%
movies.columns
# Out:
# Index(['imdbId', 'title', 'releaseYear', 'releaseDate', 'genre', 'writers',
#        'actors', 'directors', 'sequel', 'hitFlop'],
#       dtype='object')

# %%
students.values
# Out:
# array([[130,  45,  15],
#        [ 34,  12,  12],
#        [ 23,  23,  45],
#        [ 56,  67,  89]])

# %%
movies.head()
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
movies.tail()
# Out:
#          imdbId                 title  releaseYear  releaseDate     genre  \
# 1279  tt4121522  Shuruaat Ka Interval         2014  15 Aug 2014       NaN
# 1280  tt4187650      Trip to Bhangarh         2014  28 Aug 2014    Horror
# 1281  tt4190220              Zed Plus         2014  28 Nov 2014       NaN
# 1282  tt4219300       Gollu aur Pappu         2014  21 Nov 2014    Comedy
# 1283  tt4228746                   Zid         2014  28 Nov 2014  Thriller
#
#                                                 writers  \
# 1279  Aarti S. Bagdi | Amrit Raj Gupta | Krishan Hoo...
# 1280                                                NaN
# 1281  Chandra Prakash Dwivedi (screen play and dialo...
# 1282                                                NaN
# 1283                   Vivek Agnihotri | Rohit Malhotra
#
#                                                  actors  \
# 1279  Kaivalya Chheda | Rajsekhar Aningi | Avidant B...
# 1280  Manish Choudhary | Suzanna Mukherjee | Poonam ...
# ...

# %%
movies.sample(5)
# Out:
#          imdbId               title  releaseYear  releaseDate  \
# 641   tt1214948  Bhram: An Illusion         2008  04 Apr 2008
# 646   tt1218345         Dil Kabaddi         2008  05 Dec 2008
# 115   tt0335044   Dil Vil Pyar Vyar         2002  18 Oct 2002
# 635   tt1199490     Bad Luck Govind         2009  09 Jan 2009
# 1264  tt3709344          CityLights         2014  30 May 2014
#
#                           genre  \
# 641   Drama | Mystery | Romance
# 646              Comedy | Drama
# 115                     Romance
# 635      Comedy | Crime | Drama
# 1264           Drama | Thriller
#
#                                                 writers  \
# 641   Bhavani Iyer (screenplay) | Radhika Anand (dia...
# 646    Vivek Anand | Anil Senior | Lezlie George Sparkx
# 115   Sanjeev Puri (dialogue) | Sujit Sen (screenpla...
# 635                             Varun Khanna (dialogue)
# 1264  Sean Ellis (original story) | Ritesh Shah (ada...
#
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   imdbId       1284 non-null   object
#  1   title        1284 non-null   object
#  2   releaseYear  1284 non-null   int64
#  3   releaseDate  1231 non-null   object
#  4   genre        1282 non-null   object
#  5   writers      1165 non-null   object
#  6   actors       1281 non-null   object
#  7   directors    1280 non-null   object
#  8   sequel       1281 non-null   float64
#  9   hitFlop      1284 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %%
player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 261 non-null    int64
#  1   Name               261 non-null    object
#  2   longName           261 non-null    object
#  3   battingName        261 non-null    object
#  4   fieldingName       261 non-null    object
#  5   imgUrl             261 non-null    object
#  6   dob                261 non-null    object
#  7   battingStyles      261 non-null    object
#  8   longBattingStyles  261 non-null    object
#  9   bowlingStyles      261 non-null    object
#  10  longBowlingStyles  261 non-null    object
#  11  playingRoles       237 non-null    object
#  12  espn_url           261 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 26.6+ KB

# %%
player.describe()
# Out:
#                   ID
# count     261.000000
# mean    80535.095785
# std     23353.816863
# min      7593.000000
# 25%     62022.000000
# 50%     80607.000000
# 75%    102735.000000
# max    116573.000000

# %%
movies.describe()
# Out:
#        releaseYear       sequel      hitFlop
# count  1284.000000  1281.000000  1284.000000
# mean   2007.989097     0.035129     2.144081
# std       4.005243     0.188371     1.812820
# min    2001.000000     0.000000     1.000000
# 25%    2004.000000     0.000000     1.000000
# 50%    2008.000000     0.000000     1.000000
# 75%    2011.000000     0.000000     2.000000
# max    2014.000000     2.000000     9.000000

# %%
movies.isnull().sum()
# Out:
# imdbId           0
# title            0
# releaseYear      0
# releaseDate     53
# genre            2
# writers        119
# actors           3
# directors        4
# sequel           3
# hitFlop          0
# dtype: int64

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
students.rename(columns={'marks':'percentage','package':'lpa'},inplace=True)

# %%
students.sum(axis=1)
# Out:
# 0    190
# 1     58
# 2     91
# 3    212
# dtype: int64

# %%
movies['title']
# Out:
# 0                                  Albela
# 1       Lagaan: Once Upon a Time in India
# 2                Meri Biwi Ka Jawab Nahin
# 3                  Hum Tumhare Hain Sanam
# 4                              One 2 Ka 4
#                       ...
# 1279                 Shuruaat Ka Interval
# 1280                     Trip to Bhangarh
# 1281                             Zed Plus
# 1282                      Gollu aur Pappu
# 1283                                  Zid
# Name: title, Length: 1284, dtype: object

# %%
player['longBattingStyles']
# Out:
# 0      right-hand bat
# 1       left-hand bat
# 2       left-hand bat
# 3      right-hand bat
# 4       left-hand bat
#             ...
# 256    right-hand bat
# 257    right-hand bat
# 258     left-hand bat
# 259    right-hand bat
# 260    right-hand bat
# Name: longBattingStyles, Length: 261, dtype: object

# %%
player.columns
# Out:
# Index(['ID', 'Name', 'longName', 'battingName', 'fieldingName', 'imgUrl',
#        'dob', 'battingStyles', 'longBattingStyles', 'bowlingStyles',
#        'longBowlingStyles', 'playingRoles', 'espn_url'],
#       dtype='object')

# %%
player[['Name','battingStyles','playingRoles']]
# Out:
#                   Name battingStyles playingRoles
# 0           RD Gaikwad           rhb           ob
# 1               MM Ali           lhb           ob
# 2     Aravelly Avanish           lhb          NaN
# 3            DL Chahar           rhb           rm
# 4         TU Deshpande           lhb           rm
# ..                 ...           ...          ...
# 256         JD Unadkat           rhb           lm
# 257       V Viyaskanth           rhb           lb
# 258  Washington Sundar           lhb           ob
# 259           UD Yadav           rhb           ob
# 260       PW Hasaranga           rhb           lb
#
# [261 rows x 3 columns]

# %%
player.iloc[0]
# Out:
# ID                                                               95094
# Name                                                        RD Gaikwad
# longName                                               Ruturaj Gaikwad
# battingName                                                 RD Gaikwad
# fieldingName                                                   Gaikwad
# imgUrl               https://img1.hscicdn.com/image/upload/f_auto,t...
# dob                                                          31/1/1997
# battingStyles                                                      rhb
# longBattingStyles                                       right-hand bat
# bowlingStyles                                                       ob
# longBowlingStyles                                   right-arm offbreak
# playingRoles                                                        ob
# espn_url             https://www.espncricinfo.com/cricketers/rutura...
# Name: 0, dtype: object

# %%
player.iloc[1]
# Out:
# ID                                                               46597
# Name                                                            MM Ali
# longName                                                     Moeen Ali
# battingName                                                     MM Ali
# fieldingName                                                       Ali
# imgUrl               https://img1.hscicdn.com/image/upload/f_auto,t...
# dob                                                          18/6/1987
# battingStyles                                                      lhb
# longBattingStyles                                        left-hand bat
# bowlingStyles                                                       ob
# longBowlingStyles                                   right-arm offbreak
# playingRoles                                                        ob
# espn_url             https://www.espncricinfo.com/cricketers/moeen-...
# Name: 1, dtype: object

# %%
player.iloc[0:16:2]
# Out:
#         ID              Name                longName       battingName  \
# 0    95094        RD Gaikwad         Ruturaj Gaikwad        RD Gaikwad
# 2   116328  Aravelly Avanish        Aravelly Avanish  Aravelly Avanish
# 4    80607      TU Deshpande        Tushar Deshpande      TU Deshpande
# 6    74975            S Dube             Shivam Dube            S Dube
# 8   104758    RS Hangargekar  Rajvardhan Hangargekar    RS Hangargekar
# 10   95065         AJ Mandal             Ajay Mandal         AJ Mandal
# 12  101414  Mukesh Choudhary        Mukesh Choudhary  Mukesh Choudhary
# 14  105938       M Pathirana     Matheesha Pathirana       M Pathirana
#
#         fieldingName                                             imgUrl  \
# 0            Gaikwad  https://img1.hscicdn.com/image/upload/f_auto,t...
# 2   Aravelly Avanish  https://img1.hscicdn.com/image/upload/f_auto,t...
# 4          Deshpande  https://img1.hscicdn.com/image/upload/f_auto,t...
# ...

# %%
player.iloc[[0,6,19]]
# Out:
#        ID        Name          longName battingName fieldingName  \
# 0   95094  RD Gaikwad   Ruturaj Gaikwad  RD Gaikwad      Gaikwad
# 6   74975      S Dube       Shivam Dube      S Dube         Dube
# 19  64864  MJ Santner  Mitchell Santner  MJ Santner      Santner
#
#                                                imgUrl        dob  \
# 0   https://img1.hscicdn.com/image/upload/f_auto,t...  31/1/1997
# 6   https://img1.hscicdn.com/image/upload/f_auto,t...  26/6/1993
# 19  https://img1.hscicdn.com/image/upload/f_auto,t...   5/2/1992
#
#    battingStyles longBattingStyles bowlingStyles       longBowlingStyles  \
# 0            rhb    right-hand bat            ob      right-arm offbreak
# 6            lhb     left-hand bat            rm        right-arm medium
# 19           lhb     left-hand bat           sla  slow left-arm orthodox
#
#    playingRoles                                           espn_url
# 0            ob  https://www.espncricinfo.com/cricketers/rutura...
# ...

# %%
player[player['Name'] == 'RD Gaikwad']
# Out:
#       ID        Name         longName battingName fieldingName  \
# 0  95094  RD Gaikwad  Ruturaj Gaikwad  RD Gaikwad      Gaikwad
#
#                                               imgUrl        dob battingStyles  \
# 0  https://img1.hscicdn.com/image/upload/f_auto,t...  31/1/1997           rhb
#
#   longBattingStyles bowlingStyles   longBowlingStyles playingRoles  \
# 0    right-hand bat            ob  right-arm offbreak           ob
#
#                                             espn_url
# 0  https://www.espncricinfo.com/cricketers/rutura...

# %%
start_index = player[player['Name'] == 'RD Gaikwad'].index[0]
end_index = player[player['Name'] == 'Mukesh Choudhary'].index[0]
player.iloc[start_index : end_index + 1]
# Out:
#         ID              Name                longName       battingName  \
# 0    95094        RD Gaikwad         Ruturaj Gaikwad        RD Gaikwad
# 1    46597            MM Ali               Moeen Ali            MM Ali
# 2   116328  Aravelly Avanish        Aravelly Avanish  Aravelly Avanish
# 3    62022         DL Chahar           Deepak Chahar         DL Chahar
# 4    80607      TU Deshpande        Tushar Deshpande      TU Deshpande
# 5     7593          MS Dhoni                MS Dhoni          MS Dhoni
# 6    74975            S Dube             Shivam Dube            S Dube
# 7    63314        RJ Gleeson         Richard Gleeson        RJ Gleeson
# 8   104758    RS Hangargekar  Rajvardhan Hangargekar    RS Hangargekar
# 9    49247         RA Jadeja         Ravindra Jadeja         RA Jadeja
# 10   95065         AJ Mandal             Ajay Mandal         AJ Mandal
# 11   58772       DJ Mitchell          Daryl Mitchell       DJ Mitchell
# ...

# %%
player.iloc[0:6,0:6]
# Out:
#        ID              Name          longName       battingName  \
# 0   95094        RD Gaikwad   Ruturaj Gaikwad        RD Gaikwad
# 1   46597            MM Ali         Moeen Ali            MM Ali
# 2  116328  Aravelly Avanish  Aravelly Avanish  Aravelly Avanish
# 3   62022         DL Chahar     Deepak Chahar         DL Chahar
# 4   80607      TU Deshpande  Tushar Deshpande      TU Deshpande
# 5    7593          MS Dhoni          MS Dhoni          MS Dhoni
#
#        fieldingName                                             imgUrl
# 0           Gaikwad  https://img1.hscicdn.com/image/upload/f_auto,t...
# 1               Ali  https://img1.hscicdn.com/image/upload/f_auto,t...
# 2  Aravelly Avanish  https://img1.hscicdn.com/image/upload/f_auto,t...
# 3            Chahar  https://img1.hscicdn.com/image/upload/f_auto,t...
# 4         Deshpande  https://img1.hscicdn.com/image/upload/f_auto,t...
# 5             Dhoni  https://img1.hscicdn.com/image/upload/f_auto,t...
